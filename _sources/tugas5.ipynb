# %% [markdown]
# # **5.** Naive Bayes Classifier
#
# ---

# %% [markdown]
# <p align="justify">
# Naive Bayes adalah metode yang cocok untuk klasifikasi biner dan multiclass. Metode yang juga dikenal sebagai Naive Bayes Classifier ini menerapkan teknik supervised klasifikasi objek di masa depan dengan menetapkan label kelas ke instance/catatan menggunakan probabilitas bersyarat.
# </p>

# %% [markdown]
# ## Load Dataset
#
# > Import dataset Iris dan menambahkan column

# %%
import numpy as np  
import matplotlib.pyplot as plt  
import pandas as pd

url = "https://archive.ics.uci.edu/ml/machine-learning-databases/iris/iris.data"
#the imported dataset does not have the required column names so lets add it
colnames = ['sepal-length', 'sepal-width', 'petal-length', 'petal-width', 'Class']
irisdata = pd.read_csv(url, names=colnames)

# %%
irisdata
# Out:
#      sepal-length  sepal-width  petal-length  petal-width           Class
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %% [markdown]
# ## Inisialisasi Data
#
# > Membuat data training dan testing

# %%
X = irisdata.values[:,0:4]  
y = irisdata.values[:,4]  
# splitting X and y into training and testing sets
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.4, random_state=1)

# %% [markdown]
# ## Modelling
#
# > Model Naive Bayes GaussionNb

# %%
# training the model on training set
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
# making predictions on the testing set
y_pred = gnb.predict(X_test)

# %% [markdown]
# ## Test Akurasi

# %%
# comparing actual response values (y_test) with predicted response values (y_pred)
from sklearn import metrics
print("Gaussian Naive Bayes model accuracy(in %):", metrics.accuracy_score(y_test, y_pred)*100)
# Out:
# Gaussian Naive Bayes model accuracy(in %): 95.0

# %% [markdown]
# ## Prediksi
#
# > Test prediksi

# %%
data = pd.concat([pd.DataFrame(X_test, columns=colnames[:-1]), pd.DataFrame(y_test, columns=[colnames[-1]])], axis=1)
data
# Out:
#    sepal-length sepal-width petal-length petal-width            Class
# 0           5.8         4.0          1.2         0.2      Iris-setosa
# 1           5.1         2.5          3.0         1.1  Iris-versicolor
# 2           6.6         3.0          4.4         1.4  Iris-versicolor
# 3           5.4         3.9          1.3         0.4      Iris-setosa
# 4           7.9         3.8          6.4         2.0   Iris-virginica
# 5           6.3         3.3          4.7         1.6  Iris-versicolor
# 6           6.9         3.1          5.1         2.3   Iris-virginica
# 7           5.1         3.8          1.9         0.4      Iris-setosa
# 8           4.7         3.2          1.6         0.2      Iris-setosa
# 9           6.9         3.2          5.7         2.3   Iris-virginica
# 10          5.6         2.7          4.2         1.3  Iris-versicolor
# 11          5.4         3.9          1.7         0.4      Iris-setosa
# 12          7.1         3.0          5.9         2.1   Iris-virginica
# 13          6.4         3.2          4.5         1.5  Iris-versicolor
# 14          6.0         2.9          4.5         1.5  Iris-versicolor
# 15          4.4         3.2          1.3         0.2      Iris-setosa
# 16          5.8         2.6          4.0         1.2  Iris-versicolor
# 17          5.6         3.0          4.5         1.5  Iris-versicolor
# 18          5.4         3.4          1.5         0.4      Iris-setosa
# 19          5.0         3.2          1.2         0.2      Iris-setosa
# 20          5.5         2.6          4.4         1.2  Iris-versicolor
# 21          5.4         3.0          4.5         1.5  Iris-versicolor
# 22          6.7         3.0          5.0         1.7  Iris-versicolor
# 23          5.0         3.5          1.3         0.3      Iris-setosa
# 24          7.2         3.2          6.0         1.8   Iris-virginica
# 25          5.7         2.8          4.1         1.3  Iris-versicolor
# 26          5.5         4.2          1.4         0.2      Iris-setosa
# 27          5.1         3.8          1.5         0.3      Iris-setosa
# 28          6.1         2.8          4.7         1.2  Iris-versicolor
# 29          6.3         2.5          5.0         1.9   Iris-virginica
# 30          6.1         3.0          4.6         1.4  Iris-versicolor
# 31          7.7         3.0          6.1         2.3   Iris-virginica
# 32          5.6         2.5          3.9         1.1  Iris-versicolor
# 33          6.4         2.8          5.6         2.1   Iris-virginica
# 34          5.8         2.8          5.1         2.4   Iris-virginica
# 35          5.3         3.7          1.5         0.2      Iris-setosa
# 36          5.5         2.3          4.0         1.3  Iris-versicolor
# 37          5.2         3.4          1.4         0.2      Iris-setosa
# 38          6.5         2.8          4.6         1.5  Iris-versicolor
# 39          6.7         2.5          5.8         1.8   Iris-virginica
# 40          6.8         3.0          5.5         2.1   Iris-virginica
# 41          5.1         3.5          1.4         0.3      Iris-setosa
# 42          6.0         2.2          5.0         1.5   Iris-virginica
# 43          6.3         2.9          5.6         1.8   Iris-virginica
# 44          6.6         2.9          4.6         1.3  Iris-versicolor
# 45          7.7         2.6          6.9         2.3   Iris-virginica
# 46          5.7         3.8          1.7         0.3      Iris-setosa
# 47          5.0         3.6          1.4         0.2      Iris-setosa
# 48          4.8         3.0          1.4         0.3      Iris-setosa
# 49          5.2         2.7          3.9         1.4  Iris-versicolor
# 50          5.1         3.4          1.5         0.2      Iris-setosa
# 51          5.5         3.5          1.3         0.2      Iris-setosa
# 52          7.7         3.8          6.7         2.2   Iris-virginica
# 53          6.9         3.1          5.4         2.1   Iris-virginica
# 54          7.3         2.9          6.3         1.8   Iris-virginica
# 55          6.4         2.8          5.6         2.2   Iris-virginica
# 56          6.2         2.8          4.8         1.8   Iris-virginica
# 57          6.0         3.4          4.5         1.6  Iris-versicolor
# 58          7.7         2.8          6.7         2.0   Iris-virginica
# 59          5.7         3.0          4.2         1.2  Iris-versicolor

# %% [markdown]
# ## Prediksi Manual
#
# > Test prediksi seperti hitungan manual

# %%
y_pred = gnb.predict([[6.7,	3.0,	5.2,	2.3]])
y_pred[0]
# Out:
# 'Iris-virginica'
